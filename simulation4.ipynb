# %% [markdown]
# Overview of the Game
# Agents and Environment
# Lattice Structure: The simulation consists of a 100x100 two-dimensional lattice (grid), creating a total of 10,000 agents. The lattice has periodic boundary conditions, meaning the edges wrap around to form a continuous surface without borders.
#
# Resource Heterogeneity: Each site on the lattice is assigned a resource value, making it either a rich site or a poor site:
#
# Rich Sites: Have a higher resource value, determined by RICH_RESOURCE = 1 + INEQUALITY_LEVEL (where INEQUALITY_LEVEL = 10, so RICH_RESOURCE = 11).
# Poor Sites: Have a baseline resource value of POOR_RESOURCE = 1.
# Distribution: Each site has a probability RICH_SITE_PROB = 0.2 (20%) of being rich.
# Agent Strategies: Agents can adopt one of two strategies:
#
# Cooperators ('C'): Willing to cooperate with neighbors.
# Defectors ('D'): Choose to defect in interactions.
# Initialization: Agents randomly select a strategy based on INITIAL_COOPERATION_PROB = 0.5, so there is an equal chance of being a cooperator or defector at the start.
# Game Dynamics
# Interactions: At each time step, agents interact with their immediate neighbors (up to four, in the von Neumann neighborhood: north, south, east, west).
#
# Payoff Calculation: Agents accumulate payoffs based on their strategy and the strategies of their neighbors:
#
# Cooperator-Cooperator (C-C): Both cooperators gain the neighbor's resource value.
# Cooperator-Defector (C-D): The cooperator gains nothing; the defector gains a payoff.
# Defector-Cooperator (D-C): The defector gains a payoff equal to b * resource, where b is the temptation factor.
# Defector-Defector (D-D): Neither gains any payoff.
# Temptation Level: Defined by TEMPTATION_LEVEL = 0.7, used to calculate b = 2 / TEMPTATION_LEVEL ≈ 2.857.
# Strategy Update: After interactions:
#
# Agents may update their strategies by comparing payoffs with a randomly selected neighbor.
# If the neighbor's payoff is higher, the agent adopts the neighbor's strategy with a probability proportional to the payoff difference.
# This process introduces stochastic imitation, allowing for strategy changes based on success.
# Simulation Loop
# The simulation runs for 100 time steps, and at each step:
#
# Play Game: Agents interact with neighbors and calculate payoffs.
# Update Strategies: Agents may adopt new strategies based on payoffs.
# Record Cooperation Level: The fraction of cooperators is calculated and stored.
# Visualization: The lattice is plotted at time steps 1, 50, and 100 to visualize the distribution of strategies.

# %% [markdown]
# Import Libs

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import networkx as nx

# %% [markdown]
# Adjust parameters of simulation

# %%
# Adjust grid size to 100x100
GRID_SIZE = 30  # 100x100 lattice
NUM_AGENTS = GRID_SIZE * GRID_SIZE  # Total number of agents = 100^2 = 10,000
RICH_SITE_PROB = 0.0  # Fraction of rich sites
AVERAGE_SITE_PROB = 0.0  # Fraction of average sites (you can adjust as needed)
INITIAL_COOPERATION_PROB = 0.5
c = 10  # Resource contrast (c) between rich and poor sitesINEQUALITY_LEVEL
DEFECTOR_COST = 1  # A small cost or penalty for choosing defection
COOPERATION_CLUSTER_BONUS   = 0.7
PUBLIC_GOOD_BONUS=2 #r, ppublic good bonus
b = 1.1              #2 / PUBLIC_GOOD_BONUS
TEMPTATION_LEVEL = b-1
m=10 #parameter for strategy change

# Payoff matrix parameters
RICH_RESOURCE = 1 + c
AVERAGE_RESOURCE = (1 + c) / 2  # Average site resource
POOR_RESOURCE = 1

# for homo env. 
HOMOGENEOUS_RESOURCE = 1  # Set a common resource value for all agents

# %% [markdown]
# Functions regarding game

# %%
# Create a 2D grid of agents (lattice)
def create_lattice():
    G = nx.grid_2d_graph(GRID_SIZE, GRID_SIZE, periodic=True)  # 2D grid with periodic boundary
    assign_resources(G)
    #assign_resources_HOMOGENEOUS(G)
    initialize_strategies(G, INITIAL_COOPERATION_PROB)
    return G

# Assign the same resource to all sites (homogeneous environment)
def assign_resources_HOMOGENEOUS(G):

    for node in G.nodes():
        G.nodes[node]['resource'] = HOMOGENEOUS_RESOURCE
        G.nodes[node]['site_type'] = 'homogeneous'  # Optional, can remove if not needed

# Assign resources to rich, poor, and average sites
def assign_resources(G):
    for node in G.nodes():
        rand = random.random()
        if rand < RICH_SITE_PROB:
            G.nodes[node]['resource'] = RICH_RESOURCE
            G.nodes[node]['site_type'] = 'rich'
        elif rand < RICH_SITE_PROB + AVERAGE_SITE_PROB:
            G.nodes[node]['resource'] = AVERAGE_RESOURCE
            G.nodes[node]['site_type'] = 'average'
        else:
            G.nodes[node]['resource'] = POOR_RESOURCE
            G.nodes[node]['site_type'] = 'poor'

# Initialize strategies for agents (either cooperate 'C' or defect 'D')
def initialize_strategies(G, cooperation_prob):
    for node in G.nodes():
        G.nodes[node]['strategy'] = 'C' if random.random() < cooperation_prob else 'D'

# Play the game for one time step and calculate payoffs
def play_game(G):
    payoffs = {}
    for node in G.nodes():
        strategy = G.nodes[node]['strategy']
        site = G.nodes[node]['site_type']
        payoff = 0
        neighbors = list(G.neighbors(node))
        # Count cooperative neighbors for cooperation bonus
        #cooperator_neighbors = sum(1 for neighbor in neighbors if G.nodes[neighbor]['strategy'] == 'C')


        #pick one random per iteration 

        #
        
        for neighbor in neighbors:
            neighbor_strategy = G.nodes[neighbor]['strategy']
            neighbor_site = G.nodes[neighbor]['site_type']

            # Payoff matrix from the paper (rich, average, and poor site interactions)
            
            #rich-rich interaction
            if strategy == 'C' and neighbor_strategy == 'C' and site=='rich' and neighbor_site == 'rich':
                payoff += 2* c + 1 # Cooperation between cooperators
            elif strategy == 'C' and neighbor_strategy == 'D' and site=='rich' and neighbor_site == 'rich':
                payoff += c  # Cooperator interacting with defector
            elif strategy == 'D' and neighbor_strategy == 'C' and site=='rich' and neighbor_site == 'rich':
                payoff += b*c + b + c  # Defector interacting with cooperator
            elif strategy == 'D' and neighbor_strategy == 'D' and site=='rich' and neighbor_site == 'rich':
                payoff += b*c + b - 1  # Defector interacting with defector

            #rich-poor interaction
            if strategy == 'C' and neighbor_strategy == 'C' and site=='rich' and neighbor_site == 'poor':
                payoff += c + 1 # Cooperation between cooperators
            elif strategy == 'C' and neighbor_strategy == 'D' and site=='rich' and neighbor_site == 'poor':
                payoff += c  # Cooperator interacting with defector
            elif strategy == 'D' and neighbor_strategy == 'C' and site=='rich' and neighbor_site == 'poor':
                payoff += b*c + b  # Defector interacting with cooperator
            elif strategy == 'D' and neighbor_strategy == 'D' and site=='rich' and neighbor_site == 'poor':
                payoff += b*c + b - 1  # Defector interacting with defector

            #poor-rich interaction
            if strategy == 'C' and neighbor_strategy == 'C' and site=='poor' and neighbor_site == 'rich':
                payoff += c + 1 # Cooperation between cooperators
            elif strategy == 'C' and neighbor_strategy == 'D' and site=='poor' and neighbor_site == 'rich':
                payoff += 0  # Cooperator interacting with defector
            elif strategy == 'D' and neighbor_strategy == 'C' and site=='poor' and neighbor_site == 'rich':
                payoff += b+c  # Defector interacting with cooperator
            elif strategy == 'D' and neighbor_strategy == 'D' and site=='poor' and neighbor_site == 'rich':
                payoff += b - 1  # Defector interacting with defector
                
            #poor-poor interaction
            if strategy == 'C' and neighbor_strategy == 'C' and site=='poor' and neighbor_site == 'poor':
                payoff += 1 # Cooperation between cooperators
            elif strategy == 'C' and neighbor_strategy == 'D' and site=='poor' and neighbor_site == 'poor':
                payoff += 0  # Cooperator interacting with defector
            elif strategy == 'D' and neighbor_strategy == 'C' and site=='poor' and neighbor_site == 'poor':
                payoff += b  # Defector interacting with cooperator
            elif strategy == 'D' and neighbor_strategy == 'D' and site=='poor' and neighbor_site == 'poor':
                payoff += b - 1  # Defector interacting with defector


        # Add cooperation cluster bonus for cooperators
        #if strategy == 'C':
            #payoff += cooperator_neighbors * COOPERATION_CLUSTER_BONUS    # Bonus for each cooperative neighbor

        payoffs[node] = payoff
    return payoffs

# Update strategies based on payoffs and stochastic imitation
def update_strategies(G, payoffs):
    new_strategies = {}
    mutation_prob = 0.05  # Small chance of strategy mutation
    m = 10  # Exponent
    # min_payoff = min(payoffs.values())
    # offset = 0
    # if min_payoff < 0:
    #     offset = -min_payoff  # Adjust payoffs to be non-negative

    #for node in G.nodes():
    node = random.choice(list(G.nodes()))
    if random.random() < mutation_prob:
        # Mutate strategy
        current_strategy = G.nodes[node]['strategy']
        new_strategies[node] = 'C' if current_strategy == 'D' else 'D'
    else:
        neighbors = list(G.neighbors(node))
        neighbors.append(node)
        #print("nEIgh:", neighbors)
        #selected_neighbor = (0, 10) #1. sometimes this wass null
        if neighbors:
            neighbor_payoffs_m = []
            neighbor_probabilities = []
            total = 0
            for neighbor in neighbors:
                payoff = payoffs[neighbor]
                payoff_m = payoff ** m
                neighbor_payoffs_m.append((neighbor, payoff_m))
                total += payoff_m
            #total = sum(neighbor_payoffs_m[payoff_m])    
        
            if total == 0:
                selected_neighbor = random.choice(neighbors)
                new_strategies[node] = G.nodes[selected_neighbor]['strategy']
                #print("We are all defactors")
                return 

            for neighbor, payoff_m in neighbor_payoffs_m:
                neighbor_probabilities.append(payoff_m / total)
                #print("Probabilities: ",neighbor_probabilities)

            
            rand = random.random()
            #print("RAND: ",rand)
            #0.98
            #0.999999999 rand 
            for i in range(len(neighbor_probabilities)): #WRONG 
                if rand >= neighbor_probabilities[i]:
                    selected_neighbor = neighbors[i]
                    break
                rand += neighbor_probabilities[i]

            if selected_neighbor == None:
                print("ERROR: ",rand) 
            # Update strategy to the selected neighbor's strategy
            #print("Selected neighbor: ",selected_neighbor)
            #1 of number of agents
            new_strategies[node] = G.nodes[selected_neighbor]['strategy']
            print("Updated node is ", node, " with strategy ", new_strategies[node])
        else:
            # No neighbors; keep the same strategy
            new_strategies[node] = G.nodes[node]['strategy']
# # Update the strategies in the graph
# for node in G.nodes():
#     G.nodes[node]['strategy'] = new_strategies[node]

# %% [markdown]
# Plotting

# %%
# Visualization of the lattice with different colors for cooperators and defectors
def plot_lattice(G, timestep):
    """
    Plot a lattice where node color is determined by strategy and site_type.
    Cooperators (C) are blue or light blue based on site type.
    Defectors (D) are red or light red based on site type.
    """
    node_colors = []
    
    for node in G.nodes():
        strategy = G.nodes[node].get('strategy')  # 'C' or 'D'
        site_type = G.nodes[node].get('site_type')  # 'rich' or 'poor'
        #print("Site type: ", site_type)

        
        if strategy == 'C':
            if site_type == 'rich':
                node_colors.append('lightblue')  # Cooperators on rich sites
            else:
                node_colors.append('blue')       # Cooperators on poor sites
        elif strategy == 'D':
            if site_type == 'rich':
                node_colors.append('salmon') # Defectors on rich sites
            else:
                node_colors.append('red')        # Defectors on poor sites
        else:
            node_colors.append('grey')           # Default in case of missing strategy
    
    # Draw the grid with proper node colors
    pos = dict((n, n) for n in G.nodes())  # Use grid positions
    plt.figure(figsize=(8, 8))
    
    # Increase node size to remove white spaces between dots
    nx.draw(G, pos, node_color=node_colors, with_labels=False, node_size=40, edge_color='black', width=0.05)
    
    plt.title(f"Lattice at time step {timestep}")
    plt.show()

def plot_lattice_old(G, timestep):
    # Color cooperators (blue) and defectors (red)
    strategy_map = {'C': 'blue', 'D': 'red'}
    node_colors = [strategy_map[G.nodes[node]['strategy']] for node in G.nodes()]
    
    # Draw the grid with proper node colors
    pos = dict((n, n) for n in G.nodes())  # Use grid positions
    plt.figure(figsize=(8, 8))
    
    # Increase node size to remove white spaces between dots
    nx.draw(G, pos, node_color=node_colors, with_labels=False, node_size=40, edge_color='black', width=0.05)
    
    plt.title(f"Lattice OLD at time step {timestep}")
    plt.show()

# %% [markdown]
# Simulation

# %%
# Simulation loop
def simulate():
    G = create_lattice()
    cooperation_levels = []

    for t in range(100000):  # Simulate for 100 time steps
        payoffs = play_game(G)
        update_strategies(G, payoffs)
        
        num_cooperators = sum(1 for node in G.nodes() if G.nodes[node]['strategy'] == 'C')
        cooperation_level = num_cooperators / NUM_AGENTS
        cooperation_levels.append(cooperation_level)
        
        if t in [0, 1000, 5000, 9999, 10000, 50000, 99999]:
            plot_lattice(G, t+1)
            #plot_lattice_old(G, t+1)
    
    return cooperation_levels, G

# %%
# Run the simulation and plot the final state
cooperation_levels, G = simulate()

# Plot the cooperation level over time
plt.plot(cooperation_levels)
plt.xlabel("Time step")
plt.ylabel("Cooperation level")
plt.show()
# Out:
# Updated node is  (19, 16)  with strategy  C
# Updated node is  (13, 14)  with strategy  C
# Updated node is  (25, 20)  with strategy  D
# Updated node is  (9, 12)  with strategy  D
# Updated node is  (10, 3)  with strategy  D
# Updated node is  (9, 21)  with strategy  C
# Updated node is  (14, 9)  with strategy  D
# Updated node is  (14, 12)  with strategy  D
# Updated node is  (18, 23)  with strategy  D
# Updated node is  (27, 12)  with strategy  C
# Updated node is  (19, 14)  with strategy  D
# Updated node is  (1, 9)  with strategy  C
# Updated node is  (14, 6)  with strategy  C
# Updated node is  (15, 0)  with strategy  C
# Updated node is  (15, 15)  with strategy  C
# Updated node is  (15, 11)  with strategy  C
# Updated node is  (4, 18)  with strategy  C
# Updated node is  (27, 28)  with strategy  D
# Updated node is  (28, 28)  with strategy  D
# Updated node is  (7, 22)  with strategy  D
# Updated node is  (1, 0)  with strategy  C
# Updated node is  (8, 27)  with strategy  D
# Updated node is  (3, 22)  with strategy  D
# Updated node is  (27, 10)  with strategy  C
# Updated node is  (5, 27)  with strategy  C
# Updated node is  (15, 17)  with strategy  D
# Updated node is  (14, 18)  with strategy  D
# Updated node is  (11, 8)  with strategy  C
# Updated node is  (21, 1)  with strategy  D
# Updated node is  (8, 3)  with strategy  D
# Updated node is  (15, 27)  with strategy  D
# Updated node is  (0, 28)  with strategy  C
# Updated node is  (26, 16)  with strategy  C
# Updated node is  (17, 16)  with strategy  D
# Updated node is  (6, 27)  with strategy  D
# Updated node is  (19, 18)  with strategy  D
# Updated node is  (19, 10)  with strategy  D
# Updated node is  (13, 7)  with strategy  D
# Updated node is  (18, 3)  with strategy  D
# Updated node is  (18, 15)  with strategy  C
# Updated node is  (11, 21)  with strategy  C
# Updated node is  (13, 24)  with strategy  D
# Updated node is  (17, 28)  with strategy  D
# Updated node is  (29, 12)  with strategy  D
# Updated node is  (9, 3)  with strategy  D
# Updated node is  (12, 4)  with strategy  C
# Updated node is  (4, 0)  with strategy  C
# Updated node is  (27, 14)  with strategy  D
# Updated node is  (16, 15)  with strategy  C
# Updated node is  (21, 28)  with strategy  D
# Updated node is  (15, 23)  with strategy  D
# Updated node is  (7, 4)  with strategy  D
# Updated node is  (18, 3)  with strategy  D
# Updated node is  (1, 19)  with strategy  D
# Updated node is  (24, 17)  with strategy  D
# Updated node is  (15, 20)  with strategy  D
# Updated node is  (2, 19)  with strategy  C
# Updated node is  (13, 15)  with strategy  D
# Updated node is  (1, 12)  with strategy  C
# Updated node is  (29, 1)  with strategy  C
# Updated node is  (17, 24)  with strategy  C
# Updated node is  (8, 20)  with strategy  D
# Updated node is  (20, 17)  with strategy  D
# Updated node is  (12, 13)  with strategy  D
# Updated node is  (22, 1)  with strategy  C
# Updated node is  (10, 8)  with strategy  C
# Updated node is  (25, 17)  with strategy  C
# Updated node is  (16, 25)  with strategy  C
# Updated node is  (16, 24)  with strategy  C
# Updated node is  (17, 15)  with strategy  C
# Updated node is  (25, 2)  with strategy  C
# Updated node is  (9, 14)  with strategy  C
# Updated node is  (20, 14)  with strategy  D
# Updated node is  (17, 11)  with strategy  C
# Updated node is  (3, 7)  with strategy  C
# Updated node is  (7, 5)  with strategy  C
# Updated node is  (23, 23)  with strategy  D
# Updated node is  (12, 8)  with strategy  D
# Updated node is  (5, 15)  with strategy  D
# Updated node is  (11, 23)  with strategy  D
# Updated node is  (28, 29)  with strategy  C
# Updated node is  (3, 23)  with strategy  D
# Updated node is  (7, 13)  with strategy  D
# Updated node is  (29, 2)  with strategy  C
# Updated node is  (9, 17)  with strategy  C
# Updated node is  (10, 27)  with strategy  D
# Updated node is  (8, 28)  with strategy  D
# Updated node is  (27, 25)  with strategy  C
# Updated node is  (28, 11)  with strategy  C
# Updated node is  (28, 26)  with strategy  C
# Updated node is  (13, 27)  with strategy  C
# Updated node is  (0, 14)  with strategy  D
# Updated node is  (29, 22)  with strategy  D
# Updated node is  (9, 7)  with strategy  C
# Updated node is  (16, 24)  with strategy  C
# Updated node is  (22, 22)  with strategy  C
# Updated node is  (1, 2)  with strategy  C
# Updated node is  (6, 0)  with strategy  C
# Updated node is  (2, 1)  with strategy  D
# Updated node is  (6, 18)  with strategy  C
# Updated node is  (9, 2)  with strategy  C
# Updated node is  (9, 16)  with strategy  C
# Updated node is  (12, 10)  with strategy  D
# Updated node is  (12, 14)  with strategy  D
# Updated node is  (1, 1)  with strategy  D
# Updated node is  (3, 19)  with strategy  C
# Updated node is  (15, 26)  with strategy  D
# Updated node is  (27, 7)  with strategy  C
# Updated node is  (9, 18)  with strategy  D
# Updated node is  (19, 5)  with strategy  D
# Updated node is  (18, 19)  with strategy  D
# Updated node is  (12, 18)  with strategy  D
# Updated node is  (13, 11)  with strategy  C
# Updated node is  (7, 20)  with strategy  C
# Updated node is  (23, 11)  with strategy  D
# Updated node is  (1, 15)  with strategy  D
# Updated node is  (18, 19)  with strategy  D
# Updated node is  (13, 26)  with strategy  C
# Updated node is  (1, 20)  with strategy  C
# Updated node is  (26, 21)  with strategy  C
# Updated node is  (23, 3)  with strategy  D
# Updated node is  (13, 2)  with strategy  C
# Updated node is  (7, 5)  with strategy  C
# Updated node is  (25, 29)  with strategy  C
# Updated node is  (29, 15)  with strategy  C
# Updated node is  (8, 11)  with strategy  C
# Updated node is  (10, 26)  with strategy  D
# Updated node is  (11, 18)  with strategy  C
# Updated node is  (21, 20)  with strategy  C
# Updated node is  (6, 23)  with strategy  D
# Updated node is  (24, 22)  with strategy  D
# Updated node is  (14, 19)  with strategy  D
# Updated node is  (9, 13)  with strategy  C
# Updated node is  (18, 11)  with strategy  C
# Updated node is  (26, 29)  with strategy  C
# Updated node is  (8, 16)  with strategy  C
# Updated node is  (12, 7)  with strategy  D
# Updated node is  (28, 24)  with strategy  C
# Updated node is  (13, 3)  with strategy  D
# Updated node is  (29, 10)  with strategy  C
# Updated node is  (25, 2)  with strategy  C
# Updated node is  (27, 17)  with strategy  C
# Updated node is  (24, 26)  with strategy  D
# Updated node is  (18, 26)  with strategy  C
# Updated node is  (8, 15)  with strategy  C
# Updated node is  (0, 7)  with strategy  D
# Updated node is  (13, 4)  with strategy  C
# Updated node is  (19, 2)  with strategy  C
# Updated node is  (22, 17)  with strategy  C
# Updated node is  (5, 23)  with strategy  D
# Updated node is  (6, 14)  with strategy  C
# Updated node is  (19, 13)  with strategy  C
# Updated node is  (14, 20)  with strategy  C
# Updated node is  (26, 20)  with strategy  D
# Updated node is  (13, 4)  with strategy  C
# Updated node is  (11, 19)  with strategy  D
# Updated node is  (29, 28)  with strategy  C
# Updated node is  (6, 27)  with strategy  D
# Updated node is  (16, 15)  with strategy  C
# Updated node is  (29, 23)  with strategy  D
# Updated node is  (22, 24)  with strategy  C
# Updated node is  (4, 23)  with strategy  C
# Updated node is  (21, 10)  with strategy  C
# Updated node is  (26, 26)  with strategy  D
# Updated node is  (2, 4)  with strategy  C
# Updated node is  (11, 15)  with strategy  C
# Updated node is  (12, 13)  with strategy  D
# Updated node is  (18, 3)  with strategy  D
# Updated node is  (6, 1)  with strategy  C
# Updated node is  (18, 1)  with strategy  D
# Updated node is  (12, 0)  with strategy  C
# Updated node is  (8, 5)  with strategy  D
# Updated node is  (0, 8)  with strategy  C
# Updated node is  (21, 6)  with strategy  C
# Updated node is  (7, 24)  with strategy  C
# Updated node is  (6, 17)  with strategy  C
# Updated node is  (1, 18)  with strategy  D
# Updated node is  (20, 28)  with strategy  C
# Updated node is  (7, 29)  with strategy  C
# Updated node is  (8, 10)  with strategy  D
# Updated node is  (22, 11)  with strategy  D
# Updated node is  (16, 6)  with strategy  D
# Updated node is  (11, 12)  with strategy  C
# Updated node is  (5, 1)  with strategy  D
# Updated node is  (26, 16)  with strategy  C
# Updated node is  (27, 12)  with strategy  C
# Updated node is  (2, 29)  with strategy  C
# Updated node is  (27, 0)  with strategy  D
# Updated node is  (25, 7)  with strategy  D
# Updated node is  (29, 8)  with strategy  D
# Updated node is  (28, 0)  with strategy  D
# Updated node is  (5, 8)  with strategy  D
# Updated node is  (6, 24)  with strategy  D
# Updated node is  (29, 1)  with strategy  C
# Updated node is  (13, 11)  with strategy  C
# Updated node is  (10, 5)  with strategy  C
# Updated node is  (13, 7)  with strategy  D
# Updated node is  (16, 8)  with strategy  C
# Updated node is  (29, 9)  with strategy  C
# Updated node is  (19, 4)  with strategy  D
# Updated node is  (17, 0)  with strategy  C
# Updated node is  (20, 22)  with strategy  D
# Updated node is  (25, 29)  with strategy  C
# Updated node is  (24, 18)  with strategy  C
# Updated node is  (13, 23)  with strategy  C
# Updated node is  (10, 11)  with strategy  C
# Updated node is  (15, 14)  with strategy  C
# Updated node is  (23, 26)  with strategy  C
# Updated node is  (10, 21)  with strategy  C
# Updated node is  (27, 9)  with strategy  D
# Updated node is  (14, 1)  with strategy  D
# Updated node is  (25, 9)  with strategy  C
# Updated node is  (8, 23)  with strategy  D
# Updated node is  (28, 14)  with strategy  D
# Updated node is  (10, 23)  with strategy  C
# Updated node is  (21, 20)  with strategy  C
# Updated node is  (20, 20)  with strategy  C
# Updated node is  (28, 18)  with strategy  D
# Updated node is  (11, 20)  with strategy  C
# Updated node is  (1, 13)  with strategy  D
# Updated node is  (19, 25)  with strategy  D
# Updated node is  (12, 5)  with strategy  C
# Updated node is  (7, 16)  with strategy  C
# Updated node is  (0, 18)  with strategy  D
# Updated node is  (25, 11)  with strategy  C
# Updated node is  (0, 29)  with strategy  C
# Updated node is  (10, 11)  with strategy  C
# Updated node is  (9, 19)  with strategy  D
# Updated node is  (5, 11)  with strategy  C
# Updated node is  (26, 29)  with strategy  C
# Updated node is  (16, 25)  with strategy  C
# Updated node is  (15, 8)  with strategy  D
# Updated node is  (15, 11)  with strategy  C
# Updated node is  (29, 0)  with strategy  C
# Updated node is  (4, 26)  with strategy  C
# Updated node is  (16, 13)  with strategy  C
# Updated node is  (28, 16)  with strategy  D
# Updated node is  (7, 1)  with strategy  C
# Updated node is  (29, 24)  with strategy  D
# Updated node is  (5, 9)  with strategy  D
# Updated node is  (6, 24)  with strategy  D
# Updated node is  (14, 25)  with strategy  C
# Updated node is  (9, 0)  with strategy  D
# Updated node is  (15, 13)  with strategy  C
# Updated node is  (21, 21)  with strategy  C
# Updated node is  (26, 13)  with strategy  D
# Updated node is  (8, 1)  with strategy  D
# Updated node is  (28, 19)  with strategy  C
# Updated node is  (23, 26)  with strategy  C
# Updated node is  (25, 6)  with strategy  D
# Updated node is  (12, 12)  with strategy  C
# Updated node is  (20, 17)  with strategy  D
# Updated node is  (14, 19)  with strategy  D
# Updated node is  (3, 14)  with strategy  C
# Updated node is  (20, 5)  with strategy  D
# Updated node is  (5, 16)  with strategy  C
# Updated node is  (8, 16)  with strategy  C
# Updated node is  (7, 9)  with strategy  C
# Updated node is  (20, 26)  with strategy  C
# Updated node is  (25, 24)  with strategy  D
# Updated node is  (8, 18)  with strategy  D
# Updated node is  (15, 28)  with strategy  D
# Updated node is  (6, 27)  with strategy  D
# Updated node is  (19, 25)  with strategy  D
# Updated node is  (29, 19)  with strategy  C
# Updated node is  (27, 17)  with strategy  D
# Updated node is  (16, 27)  with strategy  C
# Updated node is  (28, 20)  with strategy  C
# Updated node is  (26, 22)  with strategy  C
# Updated node is  (26, 23)  with strategy  D
# Updated node is  (1, 23)  with strategy  D
# Updated node is  (15, 16)  with strategy  D
# Updated node is  (11, 28)  with strategy  D
# Updated node is  (8, 7)  with strategy  D
# Updated node is  (15, 1)  with strategy  D
# Updated node is  (2, 25)  with strategy  C
# Updated node is  (13, 13)  with strategy  D
# Updated node is  (15, 28)  with strategy  D
# Updated node is  (18, 20)  with strategy  D
# Updated node is  (6, 27)  with strategy  D
# Updated node is  (13, 3)  with strategy  D
# Updated node is  (2, 17)  with strategy  D
# Updated node is  (27, 0)  with strategy  D
# Updated node is  (23, 0)  with strategy  C
# Updated node is  (9, 12)  with strategy  D
# Updated node is  (15, 12)  with strategy  C
# Updated node is  (9, 25)  with strategy  D
# Updated node is  (7, 7)  with strategy  D
# Updated node is  (17, 18)  with strategy  D
# Updated node is  (6, 7)  with strategy  C
# Updated node is  (6, 23)  with strategy  D
# Updated node is  (3, 19)  with strategy  C
# Updated node is  (16, 26)  with strategy  D
# Updated node is  (4, 22)  with strategy  D
# Updated node is  (3, 16)  with strategy  D
# Updated node is  (4, 20)  with strategy  C
# Updated node is  (7, 12)  with strategy  C
# Updated node is  (11, 10)  with strategy  D
# Updated node is  (21, 28)  with strategy  D
# Updated node is  (13, 10)  with strategy  D
# Updated node is  (27, 3)  with strategy  C
# Updated node is  (8, 29)  with strategy  C
# Updated node is  (18, 12)  with strategy  D
# Updated node is  (0, 16)  with strategy  D
# Updated node is  (17, 11)  with strategy  C
# Updated node is  (21, 16)  with strategy  C
# Updated node is  (2, 22)  with strategy  C
# Updated node is  (22, 11)  with strategy  D
# Updated node is  (21, 11)  with strategy  D
# Updated node is  (14, 28)  with strategy  C
# Updated node is  (26, 5)  with strategy  C
# Updated node is  (9, 0)  with strategy  D
# Updated node is  (24, 3)  with strategy  D
# Updated node is  (13, 9)  with strategy  D
# Updated node is  (2, 21)  with strategy  D
# Updated node is  (10, 15)  with strategy  C
# Updated node is  (14, 7)  with strategy  D
# Updated node is  (13, 1)  with strategy  D
# Updated node is  (8, 24)  with strategy  D
# Updated node is  (15, 27)  with strategy  D
# Updated node is  (26, 7)  with strategy  D
# Updated node is  (4, 10)  with strategy  C
# Updated node is  (8, 12)  with strategy  D
# Updated node is  (16, 18)  with strategy  C
# Updated node is  (15, 16)  with strategy  D
# Updated node is  (29, 13)  with strategy  C
# Updated node is  (3, 26)  with strategy  D
# Updated node is  (10, 9)  with strategy  D
# Updated node is  (2, 23)  with strategy  C
# Updated node is  (15, 21)  with strategy  C
# Updated node is  (10, 4)  with strategy  D
# Updated node is  (1, 7)  with strategy  C
# Updated node is  (8, 13)  with strategy  C
# Updated node is  (7, 6)  with strategy  D
# Updated node is  (12, 14)  with strategy  D
# Updated node is  (7, 5)  with strategy  C
# Updated node is  (8, 12)  with strategy  D
# Updated node is  (2, 26)  with strategy  C
# Updated node is  (14, 20)  with strategy  D
# Updated node is  (27, 23)  with strategy  C
# Updated node is  (9, 5)  with strategy  D
# Updated node is  (11, 1)  with strategy  D
# Updated node is  (7, 23)  with strategy  D
# Updated node is  (22, 25)  with strategy  D
# Updated node is  (22, 26)  with strategy  D
# Updated node is  (3, 9)  with strategy  D
# Updated node is  (15, 9)  with strategy  C
# Updated node is  (21, 29)  with strategy  C
# Updated node is  (2, 22)  with strategy  C
# Updated node is  (29, 9)  with strategy  C
# Updated node is  (5, 21)  with strategy  C
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (23, 10)  with strategy  D
# Updated node is  (5, 16)  with strategy  C
# Updated node is  (28, 22)  with strategy  C
# Updated node is  (9, 19)  with strategy  D
# Updated node is  (12, 14)  with strategy  D
# Updated node is  (18, 22)  with strategy  C
# Updated node is  (24, 24)  with strategy  C
# Updated node is  (3, 28)  with strategy  C
# Updated node is  (21, 11)  with strategy  D
# Updated node is  (6, 16)  with strategy  C
# Updated node is  (28, 0)  with strategy  D
# Updated node is  (3, 16)  with strategy  D
# Updated node is  (13, 17)  with strategy  C
# Updated node is  (25, 2)  with strategy  C
# Updated node is  (5, 7)  with strategy  D
# Updated node is  (24, 23)  with strategy  D
# Updated node is  (25, 2)  with strategy  C
# Updated node is  (5, 18)  with strategy  C
# Updated node is  (3, 1)  with strategy  D
# Updated node is  (29, 12)  with strategy  D
# Updated node is  (14, 24)  with strategy  D
# Updated node is  (4, 17)  with strategy  C
# Updated node is  (10, 0)  with strategy  C
# Updated node is  (17, 15)  with strategy  C
# Updated node is  (8, 23)  with strategy  D
# Updated node is  (7, 11)  with strategy  D
# Updated node is  (12, 2)  with strategy  C
# Updated node is  (20, 20)  with strategy  C
# Updated node is  (19, 25)  with strategy  D
# Updated node is  (23, 20)  with strategy  C
# Updated node is  (22, 4)  with strategy  D
# Updated node is  (27, 7)  with strategy  C
# Updated node is  (26, 2)  with strategy  C
# Updated node is  (26, 27)  with strategy  C
# Updated node is  (19, 10)  with strategy  C
# Updated node is  (28, 14)  with strategy  D
# Updated node is  (8, 24)  with strategy  C
# Updated node is  (26, 4)  with strategy  D
# Updated node is  (28, 17)  with strategy  C
# Updated node is  (21, 3)  with strategy  D
# Updated node is  (19, 2)  with strategy  C
# Updated node is  (11, 25)  with strategy  D
# Updated node is  (24, 16)  with strategy  D
# Updated node is  (28, 3)  with strategy  C
# Updated node is  (13, 28)  with strategy  C
# Updated node is  (20, 26)  with strategy  C
# Updated node is  (15, 18)  with strategy  D
# Updated node is  (13, 26)  with strategy  C
# Updated node is  (29, 4)  with strategy  D
# Updated node is  (17, 9)  with strategy  D
# Updated node is  (21, 14)  with strategy  D
# Updated node is  (4, 2)  with strategy  D
# Updated node is  (3, 9)  with strategy  C
# Updated node is  (28, 27)  with strategy  C
# Updated node is  (25, 0)  with strategy  D
# Updated node is  (15, 10)  with strategy  C
# Updated node is  (2, 3)  with strategy  D
# Updated node is  (21, 29)  with strategy  C
# Updated node is  (9, 6)  with strategy  D
# Updated node is  (27, 23)  with strategy  C
# Updated node is  (21, 22)  with strategy  D
# Updated node is  (14, 7)  with strategy  D
# Updated node is  (16, 6)  with strategy  D
# Updated node is  (19, 16)  with strategy  D
# Updated node is  (11, 23)  with strategy  C
# Updated node is  (12, 1)  with strategy  D
# Updated node is  (29, 26)  with strategy  D
# Updated node is  (27, 21)  with strategy  C
# Updated node is  (2, 2)  with strategy  C
# Updated node is  (15, 0)  with strategy  C
# Updated node is  (16, 7)  with strategy  D
# Updated node is  (24, 2)  with strategy  D
# Updated node is  (5, 10)  with strategy  D
# Updated node is  (15, 13)  with strategy  C
# Updated node is  (13, 25)  with strategy  D
# Updated node is  (8, 20)  with strategy  D
# Updated node is  (10, 9)  with strategy  D
# Updated node is  (28, 16)  with strategy  D
# Updated node is  (16, 20)  with strategy  C
# Updated node is  (24, 12)  with strategy  D
# Updated node is  (29, 4)  with strategy  D
# Updated node is  (23, 28)  with strategy  D
# Updated node is  (13, 20)  with strategy  C
# Updated node is  (6, 13)  with strategy  C
# Updated node is  (3, 26)  with strategy  D
# Updated node is  (4, 10)  with strategy  C
# Updated node is  (16, 25)  with strategy  C
# Updated node is  (22, 15)  with strategy  D
# Updated node is  (0, 10)  with strategy  C
# Updated node is  (1, 6)  with strategy  D
# Updated node is  (9, 26)  with strategy  D
# Updated node is  (23, 17)  with strategy  C
# Updated node is  (8, 29)  with strategy  C
# Updated node is  (27, 4)  with strategy  D
# Updated node is  (16, 17)  with strategy  C
# Updated node is  (6, 22)  with strategy  D
# Updated node is  (23, 23)  with strategy  D
# Updated node is  (18, 5)  with strategy  C
# Updated node is  (2, 18)  with strategy  D
# Updated node is  (13, 17)  with strategy  C
# Updated node is  (22, 24)  with strategy  C
# Updated node is  (19, 7)  with strategy  D
# Updated node is  (21, 6)  with strategy  D
# Updated node is  (29, 23)  with strategy  D
# Updated node is  (23, 20)  with strategy  C
# Updated node is  (29, 15)  with strategy  C
# Updated node is  (12, 16)  with strategy  C
# Updated node is  (11, 14)  with strategy  C
# Updated node is  (10, 18)  with strategy  D
# Updated node is  (8, 25)  with strategy  C
# Updated node is  (20, 22)  with strategy  D
# Updated node is  (22, 20)  with strategy  C
# Updated node is  (11, 18)  with strategy  C
# Updated node is  (12, 26)  with strategy  D
# Updated node is  (23, 17)  with strategy  C
# Updated node is  (20, 12)  with strategy  D
# Updated node is  (29, 8)  with strategy  D
# Updated node is  (6, 22)  with strategy  D
# Updated node is  (21, 2)  with strategy  C
# Updated node is  (20, 19)  with strategy  C
# Updated node is  (8, 9)  with strategy  D
# Updated node is  (12, 26)  with strategy  D
# Updated node is  (25, 12)  with strategy  D
# Updated node is  (27, 16)  with strategy  D
# Updated node is  (29, 16)  with strategy  D
# Updated node is  (7, 20)  with strategy  C
# Updated node is  (26, 9)  with strategy  D
# Updated node is  (15, 3)  with strategy  D
# Updated node is  (15, 14)  with strategy  C
# Updated node is  (25, 25)  with strategy  C
# Updated node is  (14, 21)  with strategy  C
# Updated node is  (27, 11)  with strategy  D
# Updated node is  (28, 0)  with strategy  D
# Updated node is  (4, 29)  with strategy  C
# Updated node is  (0, 26)  with strategy  C
# Updated node is  (10, 27)  with strategy  D
# Updated node is  (29, 25)  with strategy  C
# Updated node is  (1, 19)  with strategy  D
# Updated node is  (26, 9)  with strategy  D
# Updated node is  (16, 3)  with strategy  C
# Updated node is  (13, 0)  with strategy  C
# Updated node is  (3, 9)  with strategy  D
# Updated node is  (15, 7)  with strategy  D
# Updated node is  (17, 5)  with strategy  D
# Updated node is  (28, 9)  with strategy  C
# Updated node is  (13, 7)  with strategy  D
# Updated node is  (8, 27)  with strategy  D
# Updated node is  (26, 19)  with strategy  D
# Updated node is  (27, 16)  with strategy  D
# Updated node is  (15, 19)  with strategy  D
# Updated node is  (0, 24)  with strategy  C
# Updated node is  (6, 3)  with strategy  C
# Updated node is  (27, 8)  with strategy  C
# Updated node is  (9, 8)  with strategy  C
# Updated node is  (20, 4)  with strategy  D
# Updated node is  (13, 14)  with strategy  C
# Updated node is  (2, 14)  with strategy  C
# Updated node is  (1, 24)  with strategy  C
# Updated node is  (18, 6)  with strategy  D
# Updated node is  (14, 28)  with strategy  C
# Updated node is  (2, 19)  with strategy  C
# Updated node is  (24, 0)  with strategy  D
# Updated node is  (22, 2)  with strategy  C
# Updated node is  (25, 12)  with strategy  D
# Updated node is  (19, 20)  with strategy  D
# Updated node is  (23, 7)  with strategy  D
# Updated node is  (8, 14)  with strategy  C
# Updated node is  (28, 2)  with strategy  C
# Updated node is  (5, 5)  with strategy  C
# Updated node is  (19, 9)  with strategy  D
# Updated node is  (4, 0)  with strategy  C
# Updated node is  (16, 5)  with strategy  C
# Updated node is  (22, 9)  with strategy  C
# Updated node is  (21, 26)  with strategy  C
# Updated node is  (23, 1)  with strategy  C
# Updated node is  (18, 13)  with strategy  C
# Updated node is  (5, 16)  with strategy  C
# Updated node is  (20, 26)  with strategy  C
# Updated node is  (1, 21)  with strategy  D
# Updated node is  (17, 8)  with strategy  C
# Updated node is  (3, 10)  with strategy  C
# Updated node is  (11, 18)  with strategy  C
# Updated node is  (28, 12)  with strategy  D
# Updated node is  (3, 13)  with strategy  D
# Updated node is  (11, 1)  with strategy  D
# Updated node is  (14, 6)  with strategy  C
# Updated node is  (25, 14)  with strategy  C
# Updated node is  (22, 27)  with strategy  C
# Updated node is  (1, 16)  with strategy  D
# Updated node is  (0, 10)  with strategy  C
# Updated node is  (6, 2)  with strategy  D
# Updated node is  (2, 19)  with strategy  C
# Updated node is  (17, 3)  with strategy  D
# Updated node is  (3, 13)  with strategy  D
# Updated node is  (19, 7)  with strategy  D
# Updated node is  (5, 4)  with strategy  C
# Updated node is  (9, 24)  with strategy  C
# Updated node is  (14, 24)  with strategy  D
# Updated node is  (1, 1)  with strategy  D
# Updated node is  (9, 18)  with strategy  D
# Updated node is  (2, 15)  with strategy  C
# Updated node is  (5, 2)  with strategy  C
# Updated node is  (19, 26)  with strategy  D
# Updated node is  (6, 22)  with strategy  D
# Updated node is  (20, 15)  with strategy  C
# Updated node is  (22, 23)  with strategy  D
# Updated node is  (27, 5)  with strategy  D
# Updated node is  (16, 27)  with strategy  C
# Updated node is  (20, 4)  with strategy  D
# Updated node is  (24, 8)  with strategy  C
# Updated node is  (6, 20)  with strategy  C
# Updated node is  (22, 10)  with strategy  C
# Updated node is  (16, 17)  with strategy  C
# Updated node is  (7, 18)  with strategy  D
# Updated node is  (20, 0)  with strategy  D
# Updated node is  (4, 14)  with strategy  C
# Updated node is  (4, 7)  with strategy  C
# Updated node is  (7, 14)  with strategy  C
# Updated node is  (9, 4)  with strategy  C
# Updated node is  (2, 13)  with strategy  D
# Updated node is  (21, 15)  with strategy  D
# Updated node is  (23, 26)  with strategy  C
# Updated node is  (18, 6)  with strategy  D
# Updated node is  (15, 22)  with strategy  C
# Updated node is  (11, 1)  with strategy  D
# Updated node is  (19, 17)  with strategy  D
# Updated node is  (23, 11)  with strategy  D
# Updated node is  (26, 10)  with strategy  C
# Updated node is  (22, 26)  with strategy  D
# Updated node is  (16, 12)  with strategy  D
# Updated node is  (29, 23)  with strategy  D
# Updated node is  (12, 24)  with strategy  C
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (2, 20)  with strategy  C
# Updated node is  (5, 5)  with strategy  C
# Updated node is  (22, 3)  with strategy  D
# Updated node is  (20, 11)  with strategy  D
# Updated node is  (14, 12)  with strategy  D
# Updated node is  (6, 24)  with strategy  D
# Updated node is  (7, 1)  with strategy  C
# Updated node is  (25, 15)  with strategy  C
# Updated node is  (11, 23)  with strategy  D
# Updated node is  (5, 22)  with strategy  C
# Updated node is  (11, 28)  with strategy  C
# Updated node is  (8, 1)  with strategy  D
# Updated node is  (21, 26)  with strategy  D
# Updated node is  (0, 24)  with strategy  C
# Updated node is  (10, 18)  with strategy  D
# Updated node is  (9, 20)  with strategy  C
# Updated node is  (14, 1)  with strategy  D
# Updated node is  (3, 27)  with strategy  C
# Updated node is  (1, 27)  with strategy  C
# Updated node is  (4, 12)  with strategy  C
# Updated node is  (5, 2)  with strategy  C
# Updated node is  (22, 13)  with strategy  C
# Updated node is  (6, 16)  with strategy  D
# Updated node is  (23, 19)  with strategy  C
# Updated node is  (4, 29)  with strategy  C
# Updated node is  (14, 14)  with strategy  D
# Updated node is  (8, 20)  with strategy  D
# Updated node is  (13, 5)  with strategy  C
# Updated node is  (25, 14)  with strategy  C
# Updated node is  (0, 22)  with strategy  C
# Updated node is  (0, 3)  with strategy  D
# Updated node is  (14, 14)  with strategy  D
# Updated node is  (18, 28)  with strategy  D
# Updated node is  (12, 26)  with strategy  D
# Updated node is  (4, 27)  with strategy  C
# Updated node is  (9, 8)  with strategy  C
# Updated node is  (18, 21)  with strategy  C
# Updated node is  (13, 5)  with strategy  C
# Updated node is  (3, 4)  with strategy  C
# Updated node is  (26, 24)  with strategy  C
# Updated node is  (14, 17)  with strategy  D
# Updated node is  (8, 29)  with strategy  C
# Updated node is  (13, 5)  with strategy  C
# Updated node is  (12, 2)  with strategy  D
# Updated node is  (21, 6)  with strategy  D
# Updated node is  (25, 0)  with strategy  D
# Updated node is  (14, 11)  with strategy  D
# Updated node is  (20, 5)  with strategy  D
# Updated node is  (2, 5)  with strategy  C
# Updated node is  (18, 16)  with strategy  C
# Updated node is  (7, 25)  with strategy  C
# Updated node is  (11, 2)  with strategy  C
# Updated node is  (21, 11)  with strategy  D
# Updated node is  (7, 2)  with strategy  C
# Updated node is  (14, 23)  with strategy  D
# Updated node is  (1, 16)  with strategy  D
# Updated node is  (23, 21)  with strategy  C
# Updated node is  (10, 13)  with strategy  D
# Updated node is  (1, 20)  with strategy  C
# Updated node is  (18, 24)  with strategy  D
# Updated node is  (26, 12)  with strategy  C
# Updated node is  (12, 24)  with strategy  C
# Updated node is  (20, 8)  with strategy  D
# Updated node is  (21, 21)  with strategy  C
# Updated node is  (8, 25)  with strategy  C
# Updated node is  (10, 17)  with strategy  D
# Updated node is  (25, 12)  with strategy  D
# Updated node is  (24, 6)  with strategy  D
# Updated node is  (7, 3)  with strategy  D
# Updated node is  (23, 19)  with strategy  C
# Updated node is  (6, 0)  with strategy  C
# Updated node is  (1, 17)  with strategy  D
# Updated node is  (10, 16)  with strategy  C
# Updated node is  (23, 22)  with strategy  D
# Updated node is  (27, 19)  with strategy  D
# Updated node is  (2, 5)  with strategy  C
# Updated node is  (13, 0)  with strategy  C
# Updated node is  (22, 12)  with strategy  D
# Updated node is  (22, 29)  with strategy  D
# Updated node is  (22, 11)  with strategy  D
# Updated node is  (27, 0)  with strategy  D
# Updated node is  (11, 6)  with strategy  D
# Updated node is  (23, 11)  with strategy  D
# Updated node is  (15, 5)  with strategy  D
# Updated node is  (29, 14)  with strategy  D
# Updated node is  (13, 29)  with strategy  D
# Updated node is  (9, 2)  with strategy  C
# Updated node is  (21, 14)  with strategy  D
# Updated node is  (0, 9)  with strategy  C
# Updated node is  (24, 29)  with strategy  D
# Updated node is  (5, 22)  with strategy  C
# Updated node is  (8, 1)  with strategy  D
# Updated node is  (29, 10)  with strategy  C
# Updated node is  (24, 16)  with strategy  D
# Updated node is  (10, 13)  with strategy  D
# Updated node is  (25, 13)  with strategy  C
# Updated node is  (21, 20)  with strategy  C
# Updated node is  (2, 14)  with strategy  C
# Updated node is  (24, 12)  with strategy  D
# Updated node is  (9, 7)  with strategy  C
# Updated node is  (11, 28)  with strategy  C
# Updated node is  (27, 28)  with strategy  D
# Updated node is  (4, 23)  with strategy  C
# Updated node is  (8, 21)  with strategy  D
# Updated node is  (20, 27)  with strategy  C
# Updated node is  (5, 1)  with strategy  D
# Updated node is  (29, 23)  with strategy  D
# Updated node is  (22, 8)  with strategy  C
# Updated node is  (22, 28)  with strategy  D
# Updated node is  (1, 12)  with strategy  C
# Updated node is  (6, 12)  with strategy  C
# Updated node is  (24, 15)  with strategy  C
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (18, 17)  with strategy  D
# Updated node is  (20, 11)  with strategy  D
# Updated node is  (15, 13)  with strategy  C
# Updated node is  (26, 2)  with strategy  C
# Updated node is  (8, 27)  with strategy  D
# Updated node is  (22, 12)  with strategy  D
# Updated node is  (17, 18)  with strategy  D
# Updated node is  (23, 21)  with strategy  C
# Updated node is  (7, 12)  with strategy  C
# Updated node is  (13, 10)  with strategy  D
# Updated node is  (16, 14)  with strategy  D
# Updated node is  (15, 15)  with strategy  C
# Updated node is  (5, 3)  with strategy  D
# Updated node is  (16, 2)  with strategy  D
# Updated node is  (16, 25)  with strategy  C
# Updated node is  (5, 0)  with strategy  D
# Updated node is  (8, 26)  with strategy  D
# Updated node is  (23, 0)  with strategy  C
# Updated node is  (7, 8)  with strategy  D
# Updated node is  (1, 16)  with strategy  D
# Updated node is  (10, 23)  with strategy  C
# Updated node is  (21, 21)  with strategy  C
# Updated node is  (25, 12)  with strategy  C
# Updated node is  (1, 15)  with strategy  D
# Updated node is  (0, 29)  with strategy  C
# Updated node is  (6, 21)  with strategy  C
# Updated node is  (11, 2)  with strategy  C
# Updated node is  (27, 1)  with strategy  D
# Updated node is  (16, 11)  with strategy  C
# Updated node is  (14, 7)  with strategy  D
# Updated node is  (27, 11)  with strategy  C
# Updated node is  (26, 26)  with strategy  D
# Updated node is  (12, 0)  with strategy  C
# Updated node is  (0, 27)  with strategy  C
# Updated node is  (22, 7)  with strategy  D
# Updated node is  (18, 24)  with strategy  D
# Updated node is  (10, 4)  with strategy  D
# Updated node is  (14, 28)  with strategy  C
# Updated node is  (1, 1)  with strategy  D
# Updated node is  (23, 22)  with strategy  D
# Updated node is  (26, 25)  with strategy  D
# Updated node is  (16, 25)  with strategy  C
# Updated node is  (12, 19)  with strategy  D
# Updated node is  (14, 20)  with strategy  D
# Updated node is  (20, 18)  with strategy  C
# Updated node is  (20, 15)  with strategy  C
# Updated node is  (24, 16)  with strategy  C
# Updated node is  (3, 9)  with strategy  C
# Updated node is  (13, 4)  with strategy  C
# Updated node is  (22, 29)  with strategy  D
# Updated node is  (2, 8)  with strategy  C
# Updated node is  (14, 13)  with strategy  C
# Updated node is  (8, 7)  with strategy  D
# Updated node is  (0, 25)  with strategy  C
# Updated node is  (5, 29)  with strategy  C
# Updated node is  (2, 15)  with strategy  C
# Updated node is  (25, 22)  with strategy  D
# Updated node is  (1, 0)  with strategy  C
# Updated node is  (0, 23)  with strategy  D
# Updated node is  (13, 27)  with strategy  C
# Updated node is  (26, 3)  with strategy  C
# Updated node is  (12, 7)  with strategy  D
# Updated node is  (16, 0)  with strategy  C
# Updated node is  (17, 17)  with strategy  D
# Updated node is  (7, 18)  with strategy  D
# Updated node is  (1, 3)  with strategy  D
# Updated node is  (23, 23)  with strategy  D
# Updated node is  (17, 11)  with strategy  C
# Updated node is  (26, 29)  with strategy  D
# Updated node is  (11, 27)  with strategy  C
# Updated node is  (15, 13)  with strategy  C
# Updated node is  (28, 2)  with strategy  D
# Updated node is  (2, 18)  with strategy  D
# Updated node is  (20, 14)  with strategy  D
# Updated node is  (19, 15)  with strategy  C
# Updated node is  (0, 20)  with strategy  C
# Updated node is  (0, 24)  with strategy  C
# Updated node is  (4, 21)  with strategy  D
# Updated node is  (7, 6)  with strategy  D
# Updated node is  (21, 27)  with strategy  C
# Updated node is  (18, 16)  with strategy  C
# Updated node is  (5, 16)  with strategy  C
# Updated node is  (29, 21)  with strategy  C
# Updated node is  (2, 5)  with strategy  C
# Updated node is  (15, 14)  with strategy  C
# Updated node is  (6, 12)  with strategy  D
# Updated node is  (22, 9)  with strategy  C
# Updated node is  (15, 29)  with strategy  D
# Updated node is  (3, 20)  with strategy  C
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (11, 21)  with strategy  C
# Updated node is  (14, 11)  with strategy  D
# Updated node is  (11, 11)  with strategy  C
# Updated node is  (6, 19)  with strategy  D
# Updated node is  (28, 26)  with strategy  D
# Updated node is  (12, 12)  with strategy  C
# Updated node is  (21, 5)  with strategy  C
# Updated node is  (10, 19)  with strategy  D
# Updated node is  (29, 11)  with strategy  C
# Updated node is  (29, 23)  with strategy  D
# Updated node is  (17, 8)  with strategy  C
# Updated node is  (4, 24)  with strategy  D
# Updated node is  (17, 24)  with strategy  C
# Updated node is  (23, 26)  with strategy  C
# Updated node is  (0, 2)  with strategy  C
# Updated node is  (17, 22)  with strategy  D
# Updated node is  (16, 14)  with strategy  C
# Updated node is  (18, 27)  with strategy  D
# Updated node is  (11, 26)  with strategy  D
# Updated node is  (4, 2)  with strategy  D
# Updated node is  (21, 15)  with strategy  D
# Updated node is  (26, 10)  with strategy  C
# Updated node is  (10, 10)  with strategy  D
# Updated node is  (11, 6)  with strategy  D
# Updated node is  (17, 16)  with strategy  D
# Updated node is  (9, 18)  with strategy  D
# Updated node is  (19, 28)  with strategy  D
# Updated node is  (26, 13)  with strategy  D
# Updated node is  (13, 2)  with strategy  C
# Updated node is  (12, 1)  with strategy  D
# Updated node is  (14, 22)  with strategy  D
# Updated node is  (5, 3)  with strategy  D
# Updated node is  (8, 26)  with strategy  D
# Updated node is  (28, 20)  with strategy  C
# Updated node is  (9, 4)  with strategy  C
# Updated node is  (28, 24)  with strategy  C
# Updated node is  (20, 4)  with strategy  D
# Updated node is  (29, 28)  with strategy  C
# Updated node is  (15, 15)  with strategy  C
# Updated node is  (2, 22)  with strategy  C
# Updated node is  (1, 3)  with strategy  D
# Updated node is  (9, 23)  with strategy  C
# Updated node is  (12, 29)  with strategy  C
# Updated node is  (29, 7)  with strategy  C
# Updated node is  (19, 26)  with strategy  D
# Updated node is  (4, 22)  with strategy  D
# Updated node is  (22, 26)  with strategy  D
# Updated node is  (13, 19)  with strategy  C
# Updated node is  (8, 17)  with strategy  C
# Updated node is  (13, 0)  with strategy  C
# Updated node is  (5, 10)  with strategy  D
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (5, 22)  with strategy  C
# Updated node is  (26, 5)  with strategy  C
# Updated node is  (4, 29)  with strategy  C
# Updated node is  (28, 12)  with strategy  D
# Updated node is  (4, 14)  with strategy  C
# Updated node is  (27, 1)  with strategy  D
# Updated node is  (10, 5)  with strategy  C
# Updated node is  (22, 4)  with strategy  D
# Updated node is  (29, 19)  with strategy  C
# Updated node is  (15, 17)  with strategy  D
# Updated node is  (25, 7)  with strategy  D
# Updated node is  (5, 17)  with strategy  C
# Updated node is  (15, 23)  with strategy  D
# Updated node is  (14, 2)  with strategy  C
# Updated node is  (27, 12)  with strategy  D
# Updated node is  (18, 25)  with strategy  D
# Updated node is  (21, 11)  with strategy  D
# Updated node is  (7, 1)  with strategy  C
# Updated node is  (29, 24)  with strategy  D
# Updated node is  (6, 12)  with strategy  C
# Updated node is  (15, 10)  with strategy  C
# Updated node is  (25, 29)  with strategy  C
# Updated node is  (25, 7)  with strategy  D
# Updated node is  (15, 24)  with strategy  D
# Updated node is  (26, 21)  with strategy  C
# Updated node is  (18, 1)  with strategy  D
# Updated node is  (20, 19)  with strategy  C
# Updated node is  (13, 8)  with strategy  C
# Updated node is  (10, 27)  with strategy  D
# Updated node is  (2, 21)  with strategy  D
# Updated node is  (26, 8)  with strategy  D
# Updated node is  (11, 9)  with strategy  D
# Updated node is  (27, 11)  with strategy  C
# Updated node is  (23, 24)  with strategy  D
# Updated node is  (25, 2)  with strategy  C
# Updated node is  (28, 2)  with strategy  D
# Updated node is  (7, 4)  with strategy  C
# Updated node is  (8, 24)  with strategy  D
# Updated node is  (15, 18)  with strategy  D
# Updated node is  (26, 1)  with strategy  D
# Updated node is  (11, 0)  with strategy  C
# Updated node is  (7, 16)  with strategy  C
# Updated node is  (14, 19)  with strategy  D
# Updated node is  (20, 21)  with strategy  C
# Updated node is  (23, 19)  with strategy  C
# Updated node is  (16, 22)  with strategy  D
# Updated node is  (23, 22)  with strategy  D
# Updated node is  (2, 4)  with strategy  C
# Updated node is  (28, 11)  with strategy  C
# Updated node is  (22, 15)  with strategy  D
# Updated node is  (18, 17)  with strategy  D
# Updated node is  (9, 12)  with strategy  D
# Updated node is  (20, 17)  with strategy  D
# Updated node is  (28, 13)  with strategy  D
# Updated node is  (15, 12)  with strategy  C
# Updated node is  (28, 1)  with strategy  D
# Updated node is  (3, 18)  with strategy  C
# Updated node is  (22, 26)  with strategy  D
# Updated node is  (2, 17)  with strategy  D
# Updated node is  (29, 10)  with strategy  C
# Updated node is  (5, 21)  with strategy  C
# Updated node is  (5, 16)  with strategy  C
# Updated node is  (28, 23)  with strategy  D
# Updated node is  (3, 5)  with strategy  C
# Updated node is  (22, 4)  with strategy  D
# Updated node is  (0, 9)  with strategy  C
# Updated node is  (11, 27)  with strategy  C
# Updated node is  (0, 12)  with strategy  C
# Updated node is  (27, 10)  with strategy  C
# Updated node is  (18, 13)  with strategy  C
# Updated node is  (21, 15)  with strategy  D
# Updated node is  (16, 5)  with strategy  C
# Updated node is  (9, 24)  with strategy  C
# Updated node is  (0, 17)  with strategy  D
# Updated node is  (20, 8)  with strategy  C
# Updated node is  (3, 11)  with strategy  D
# Updated node is  (20, 22)  with strategy  D
# Updated node is  (25, 3)  with strategy  C
# Updated node is  (17, 5)  with strategy  D
# Updated node is  (28, 0)  with strategy  D
# Updated node is  (0, 15)  with strategy  C
# Updated node is  (4, 28)  with strategy  C
# Updated node is  (11, 29)  with strategy  D
# Updated node is  (24, 11)  with strategy  C
# Updated node is  (21, 22)  with strategy  D
# Updated node is  (14, 26)  with strategy  C
# Updated node is  (16, 10)  with strategy  D
# Updated node is  (4, 13)  with strategy  D
# Updated node is  (17, 14)  with strategy  C
# Updated node is  (18, 8)  with strategy  C
# Updated node is  (20, 3)  with strategy  C
# Updated node is  (29, 28)  with strategy  C
# Updated node is  (12, 19)  with strategy  D
# Updated node is  (18, 18)  with strategy  D
# Updated node is  (18, 27)  with strategy  D
# Updated node is  (3, 24)  with strategy  C
# Updated node is  (3, 20)  with strategy  C
# Updated node is  (12, 0)  with strategy  C
# Updated node is  (11, 21)  with strategy  C
# Updated node is  (6, 7)  with strategy  C
# Updated node is  (13, 4)  with strategy  C
# Updated node is  (29, 6)  with strategy  C
# Updated node is  (28, 19)  with strategy  C
# Updated node is  (5, 22)  with strategy  C
# Updated node is  (4, 7)  with strategy  C
# Updated node is  (0, 9)  with strategy  C
# Updated node is  (13, 22)  with strategy  D
# Updated node is  (15, 4)  with strategy  D
# Updated node is  (12, 9)  with strategy  C
# Updated node is  (18, 8)  with strategy  C
# Updated node is  (18, 10)  with strategy  D
# Updated node is  (16, 18)  with strategy  C
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (3, 14)  with strategy  C
# Updated node is  (28, 16)  with strategy  D
# Updated node is  (3, 29)  with strategy  C
# Updated node is  (18, 6)  with strategy  D
# Updated node is  (5, 21)  with strategy  C
# Updated node is  (2, 5)  with strategy  C
# Updated node is  (17, 13)  with strategy  C
# Updated node is  (21, 9)  with strategy  C
# Updated node is  (15, 8)  with strategy  D
# Updated node is  (27, 17)  with strategy  C
# Updated node is  (25, 19)  with strategy  C
# Updated node is  (22, 27)  with strategy  C
# Updated node is  (2, 26)  with strategy  C
# Updated node is  (9, 0)  with strategy  D
# Updated node is  (16, 27)  with strategy  C
# Updated node is  (20, 26)  with strategy  C
# Updated node is  (1, 22)  with strategy  D
# Updated node is  (11, 15)  with strategy  C
# Updated node is  (21, 0)  with strategy  D
# Updated node is  (29, 27)  with strategy  C
# Updated node is  (12, 27)  with strategy  D
# Updated node is  (21, 25)  with strategy  C
# Updated node is  (25, 24)  with strategy  D
# Updated node is  (22, 3)  with strategy  C
# Updated node is  (17, 28)  with strategy  D
# Updated node is  (26, 27)  with strategy  C
# Updated node is  (3, 11)  with strategy  D
# Updated node is  (0, 19)  with strategy  C
# Updated node is  (7, 21)  with strategy  C
# Updated node is  (20, 14)  with strategy  D
# Updated node is  (9, 2)  with strategy  C
# Updated node is  (26, 10)  with strategy  C
# Updated node is  (26, 29)  with strategy  D
# Updated node is  (15, 16)  with strategy  D
# Updated node is  (11, 10)  with strategy  D
# Updated node is  (10, 22)  with strategy  D
# Updated node is  (4, 17)  with strategy  C
# Updated node is  (15, 18)  with strategy  D
# Updated node is  (25, 29)  with strategy  C
# Updated node is  (4, 28)  with strategy  C
# Updated node is  (8, 25)  with strategy  C
# Updated node is  (10, 1)  with strategy  D
# Updated node is  (4, 23)  with strategy  C
# Updated node is  (17, 6)  with strategy  C
# Updated node is  (18, 13)  with strategy  C
# Updated node is  (7, 16)  with strategy  C
# Updated node is  (1, 21)  with strategy  D
# Updated node is  (27, 1)  with strategy  D
# Updated node is  (8, 7)  with strategy  C
# Updated node is  (5, 29)  with strategy  C
# Updated node is  (11, 7)  with strategy  D
# Updated node is  (29, 15)  with strategy  C
# Updated node is  (0, 29)  with strategy  C
# Updated node is  (1, 26)  with strategy  D
# Updated node is  (28, 21)  with strategy  D
# Updated node is  (13, 16)  with strategy  D
# Updated node is  (15, 23)  with strategy  D
# Updated node is  (19, 28)  with strategy  D
# Updated node is  (26, 14)  with strategy  C
# Updated node is  (17, 16)  with strategy  D
# Updated node is  (29, 18)  with strategy  D
# Updated node is  (19, 6)  with strategy  C
# Updated node is  (27, 29)  with strategy  C
# Updated node is  (13, 9)  with strategy  C
# Updated node is  (17, 25)  with strategy  D
# Updated node is  (12, 12)  with strategy  C
# Updated node is  (8, 23)  with strategy  D
# Updated node is  (7, 6)  with strategy  D
# Updated node is  (8, 28)  with strategy  D
# Updated node is  (22, 22)  with strategy  C
# Updated node is  (29, 10)  with strategy  C
# Updated node is  (5, 26)  with strategy  C
# Updated node is  (12, 5)  with strategy  C
# Updated node is  (3, 2)  with strategy  C
# Updated node is  (11, 13)  with strategy  D
# Updated node is  (25, 3)  with strategy  D
# Updated node is  (14, 11)  with strategy  D
# Updated node is  (9, 3)  with strategy  D
# Updated node is  (8, 21)  with strategy  D
# Updated node is  (4, 28)  with strategy  C
# Updated node is  (22, 11)  with strategy  D
# Updated node is  (13, 16)  with strategy  D
# Updated node is  (14, 9)  with strategy  D
# Updated node is  (19, 11)  with strategy  C
# Updated node is  (0, 18)  with strategy  D
# Updated node is  (17, 7)  with strategy  D
# Updated node is  (27, 29)  with strategy  C
# Updated node is  (13, 10)  with strategy  D
# Updated node is  (9, 19)  with strategy  D
# Updated node is  (15, 11)  with strategy  C
# Updated node is  (6, 3)  with strategy  C
# Updated node is  (6, 14)  with strategy  C
# Updated node is  (25, 28)  with strategy  D
# Updated node is  (25, 23)  with strategy  D
# Updated node is  (1, 14)  with strategy  C
# Updated node is  (17, 16)  with strategy  D
# Updated node is  (28, 7)  with strategy  D
# Updated node is  (29, 4)  with strategy  D
# Updated node is  (5, 19)  with strategy  C
# Updated node is  (5, 20)  with strategy  C
# Updated node is  (23, 19)  with strategy  C
# Updated node is  (18, 1)  with strategy  D
# Updated node is  (14, 10)  with strategy  D
# Updated node is  (2, 0)  with strategy  C
# Updated node is  (6, 8)  with strategy  C
# Updated node is  (26, 13)  with strategy  D
# Updated node is  (19, 14)  with strategy  D
# Updated node is  (25, 28)  with strategy  D
# Updated node is  (20, 9)  with strategy  C
# Updated node is  (7, 23)  with strategy  D
# Updated node is  (8, 14)  with strategy  C
# Updated node is  (28, 25)  with strategy  C
# Updated node is  (1, 23)  with strategy  D
# Updated node is  (12, 1)  with strategy  D
# Updated node is  (7, 2)  with strategy  C
# Updated node is  (20, 23)  with strategy  D
# Updated node is  (0, 7)  with strategy  D
# Updated node is  (5, 14)  with strategy  C
# Updated node is  (24, 18)  with strategy  C
# Updated node is  (15, 21)  with strategy  C
# Updated node is  (26, 3)  with strategy  C
# Updated node is  (26, 25)  with strategy  D
# Updated node is  (20, 28)  with strategy  C
# Updated node is  (3, 11)  with strategy  C
# Updated node is  (22, 28)  with strategy  D
# Updated node is  (4, 18)  with strategy  C
# Updated node is  (24, 21)  with strategy  D
# Updated node is  (27, 16)  with strategy  D
# Updated node is  (3, 27)  with strategy  C
# Updated node is  (10, 5)  with strategy  C
# Updated node is  (19, 5)  with strategy  D
# Updated node is  (18, 1)  with strategy  D
# Updated node is  (1, 26)  with strategy  D
# Updated node is  (5, 12)  with strategy  C
# Updated node is  (6, 0)  with strategy  C
# Updated node is  (11, 7)  with strategy  D
# Updated node is  (18, 23)  with strategy  D
# Updated node is  (3, 4)  with strategy  C
# Updated node is  (20, 0)  with strategy  D
# Updated node is  (29, 9)  with strategy  C
# Updated node is  (20, 8)  with strategy  D
# Updated node is  (21, 15)  with strategy  D
# Updated node is  (18, 0)  with strategy  D
# Updated node is  (29, 6)  with strategy  C
# Updated node is  (19, 21)  with strategy  D
# Updated node is  (8, 24)  with strategy  D
# Updated node is  (19, 1)  with strategy  C
# Updated node is  (11, 28)  with strategy  D
# Updated node is  (10, 26)  with strategy  D
# Updated node is  (24, 8)  with strategy  C
# Updated node is  (27, 18)  with strategy  D
# Updated node is  (8, 1)  with strategy  D
# Updated node is  (25, 26)  with strategy  C
# ...
# Updated node is  (24, 19)  with strategy  D
# Updated node is  (19, 13)  with strategy  D
# Updated node is  (0, 3)  with strategy  D
# Updated node is  (1, 21)  with strategy  D
# Updated node is  (12, 14)  with strategy  D
# Updated node is  (0, 14)  with strategy  D
# Updated node is  (1, 1)  with strategy  D
# Updated node is  (16, 12)  with strategy  D
# Updated node is  (7, 21)  with strategy  C
# Updated node is  (25, 10)  with strategy  C
# Updated node is  (27, 5)  with strategy  D
# Updated node is  (3, 20)  with strategy  C
# Updated node is  (18, 21)  with strategy  C
# Updated node is  (25, 10)  with strategy  C
# Updated node is  (17, 4)  with strategy  D
# Updated node is  (25, 25)  with strategy  C
# Updated node is  (5, 11)  with strategy  C
# Updated node is  (25, 6)  with strategy  D
# Updated node is  (23, 11)  with strategy  D
# Updated node is  (26, 8)  with strategy  D
# Updated node is  (13, 5)  with strategy  C
# Updated node is  (20, 20)  with strategy  C
# Updated node is  (20, 29)  with strategy  C
# Updated node is  (28, 1)  with strategy  D
# Updated node is  (18, 20)  with strategy  D
# Updated node is  (15, 14)  with strategy  C
# Updated node is  (23, 20)  with strategy  D
# Updated node is  (11, 15)  with strategy  C
# Updated node is  (28, 23)  with strategy  D
# Updated node is  (8, 15)  with strategy  C
# Updated node is  (17, 24)  with strategy  C
# Updated node is  (12, 29)  with strategy  C
# Updated node is  (27, 21)  with strategy  C
# Updated node is  (20, 0)  with strategy  D
# Updated node is  (5, 6)  with strategy  D
# Updated node is  (27, 21)  with strategy  C
# Updated node is  (22, 15)  with strategy  D
# Updated node is  (16, 13)  with strategy  C
# Updated node is  (11, 21)  with strategy  C
# Updated node is  (1, 20)  with strategy  C
# Updated node is  (27, 3)  with strategy  C
# Updated node is  (21, 24)  with strategy  C
# Updated node is  (15, 8)  with strategy  D
# Updated node is  (9, 28)  with strategy  C
# Updated node is  (8, 25)  with strategy  C
# Updated node is  (9, 3)  with strategy  D
# Updated node is  (19, 0)  with strategy  C
# Updated node is  (11, 14)  with strategy  C
# Updated node is  (1, 15)  with strategy  D
# Updated node is  (11, 13)  with strategy  D
# Updated node is  (10, 0)  with strategy  C
# Updated node is  (21, 2)  with strategy  C
# Updated node is  (21, 12)  with strategy  C
# Updated node is  (21, 10)  with strategy  C
# Updated node is  (15, 18)  with strategy  D
# Updated node is  (5, 9)  with strategy  D
# Updated node is  (13, 5)  with strategy  C
# Updated node is  (0, 17)  with strategy  D
# Updated node is  (28, 14)  with strategy  D
# Updated node is  (15, 17)  with strategy  D
# Updated node is  (29, 25)  with strategy  C
# Updated node is  (25, 14)  with strategy  C
# Updated node is  (19, 14)  with strategy  D
# Updated node is  (21, 27)  with strategy  C
# Updated node is  (18, 11)  with strategy  C
# Updated node is  (12, 1)  with strategy  D
# Updated node is  (29, 23)  with strategy  D
# Updated node is  (22, 9)  with strategy  C
# Updated node is  (8, 23)  with strategy  D
# Updated node is  (8, 5)  with strategy  C
# Updated node is  (7, 25)  with strategy  C
# Updated node is  (14, 5)  with strategy  C
# Updated node is  (2, 22)  with strategy  C
# Updated node is  (25, 7)  with strategy  D
# Updated node is  (12, 13)  with strategy  D
# Updated node is  (29, 12)  with strategy  D
# Updated node is  (9, 8)  with strategy  C
# Updated node is  (13, 29)  with strategy  D
# Updated node is  (19, 4)  with strategy  D
# Updated node is  (14, 2)  with strategy  C
# Updated node is  (22, 10)  with strategy  C
# Updated node is  (9, 14)  with strategy  C
# Updated node is  (4, 18)  with strategy  C
# Updated node is  (16, 16)  with strategy  C
# Updated node is  (26, 7)  with strategy  D
# Updated node is  (20, 18)  with strategy  C
# Updated node is  (0, 6)  with strategy  C
# Updated node is  (15, 22)  with strategy  C
# Updated node is  (16, 27)  with strategy  C
# Updated node is  (22, 28)  with strategy  D
# Updated node is  (20, 25)  with strategy  C
# Updated node is  (15, 26)  with strategy  D
# Updated node is  (6, 29)  with strategy  C
# Updated node is  (8, 8)  with strategy  C
# Updated node is  (10, 24)  with strategy  C
# Updated node is  (29, 21)  with strategy  C
# Updated node is  (17, 12)  with strategy  D
# Updated node is  (17, 0)  with strategy  C
# Updated node is  (3, 0)  with strategy  D
# Updated node is  (19, 19)  with strategy  D
# Updated node is  (25, 7)  with strategy  D
# Updated node is  (17, 15)  with strategy  C
# Updated node is  (16, 1)  with strategy  D
# Updated node is  (0, 5)  with strategy  C
# Updated node is  (20, 27)  with strategy  D
# Updated node is  (24, 22)  with strategy  D
# Updated node is  (5, 13)  with strategy  D
# Updated node is  (2, 4)  with strategy  C
# Updated node is  (19, 29)  with strategy  C
# Updated node is  (12, 4)  with strategy  C
# Updated node is  (15, 22)  with strategy  C
# Updated node is  (22, 12)  with strategy  D
# Updated node is  (2, 0)  with strategy  C
# Updated node is  (5, 24)  with strategy  D
# Updated node is  (6, 17)  with strategy  C
# Updated node is  (2, 1)  with strategy  D
# Updated node is  (12, 3)  with strategy  C
# Updated node is  (0, 15)  with strategy  C
# Updated node is  (0, 18)  with strategy  D
# Updated node is  (24, 2)  with strategy  D
# Updated node is  (24, 24)  with strategy  C
# Updated node is  (25, 1)  with strategy  C
# Updated node is  (11, 26)  with strategy  D
# Updated node is  (12, 26)  with strategy  D
# Updated node is  (8, 11)  with strategy  C
# Updated node is  (18, 13)  with strategy  C
# Updated node is  (25, 15)  with strategy  D
# Updated node is  (11, 11)  with strategy  C
# Updated node is  (7, 27)  with strategy  C
# Updated node is  (15, 9)  with strategy  C
# Updated node is  (3, 25)  with strategy  D
# Updated node is  (25, 16)  with strategy  C
# Updated node is  (14, 10)  with strategy  D
# Updated node is  (1, 26)  with strategy  D
# Updated node is  (14, 4)  with strategy  C
# Updated node is  (1, 22)  with strategy  D
# Updated node is  (21, 16)  with strategy  C
# Updated node is  (26, 12)  with strategy  C
# Updated node is  (5, 11)  with strategy  C
# Updated node is  (3, 23)  with strategy  D
# Updated node is  (6, 23)  with strategy  D
# Updated node is  (13, 14)  with strategy  C
# Updated node is  (0, 0)  with strategy  C
# Updated node is  (23, 4)  with strategy  C
# Updated node is  (23, 11)  with strategy  D
# Updated node is  (4, 5)  with strategy  C
# Updated node is  (25, 11)  with strategy  C
# Updated node is  (16, 17)  with strategy  C
# Updated node is  (1, 15)  with strategy  D
# Updated node is  (17, 10)  with strategy  D
# Updated node is  (23, 8)  with strategy  D
# Updated node is  (22, 7)  with strategy  D
# Updated node is  (15, 11)  with strategy  C
# Updated node is  (22, 1)  with strategy  C
# Updated node is  (12, 1)  with strategy  D
# Updated node is  (6, 28)  with strategy  C
# Updated node is  (5, 0)  with strategy  D
# Updated node is  (1, 17)  with strategy  D
# Updated node is  (13, 17)  with strategy  C
# Updated node is  (8, 5)  with strategy  C
# Updated node is  (5, 19)  with strategy  C
# Updated node is  (17, 2)  with strategy  D
# Updated node is  (20, 4)  with strategy  D
# Updated node is  (29, 26)  with strategy  D
# Updated node is  (23, 15)  with strategy  C
# Updated node is  (19, 9)  with strategy  D
# Updated node is  (13, 16)  with strategy  D
# Updated node is  (21, 19)  with strategy  C
# Updated node is  (19, 9)  with strategy  D
# Updated node is  (3, 20)  with strategy  C
# Updated node is  (29, 22)  with strategy  D
# Updated node is  (21, 13)  with strategy  C
# Updated node is  (8, 26)  with strategy  D
# Updated node is  (26, 16)  with strategy  C
# Updated node is  (8, 0)  with strategy  C
# Updated node is  (3, 10)  with strategy  C
# Updated node is  (18, 2)  with strategy  C
# Updated node is  (10, 17)  with strategy  D
# Updated node is  (14, 24)  with strategy  D
# Updated node is  (1, 15)  with strategy  D
# Updated node is  (20, 25)  with strategy  C
# Updated node is  (4, 19)  with strategy  C
# Updated node is  (16, 26)  with strategy  C
# Updated node is  (9, 17)  with strategy  C
# Updated node is  (15, 10)  with strategy  C
# Updated node is  (12, 15)  with strategy  C
# Updated node is  (21, 26)  with strategy  D
# Updated node is  (17, 9)  with strategy  D
# Updated node is  (21, 9)  with strategy  C
# Updated node is  (4, 17)  with strategy  C
# Updated node is  (2, 5)  with strategy  C
# Updated node is  (27, 23)  with strategy  C
# Updated node is  (9, 12)  with strategy  D
# Updated node is  (7, 23)  with strategy  D
# Updated node is  (22, 29)  with strategy  D
# Updated node is  (4, 11)  with strategy  D
# Updated node is  (8, 15)  with strategy  C
# Updated node is  (9, 1)  with strategy  C
# Updated node is  (20, 26)  with strategy  C
# Updated node is  (17, 13)  with strategy  C
# Updated node is  (2, 1)  with strategy  D
# Updated node is  (9, 18)  with strategy  D
# Updated node is  (7, 8)  with strategy  D
# Updated node is  (20, 14)  with strategy  D
# Updated node is  (20, 21)  with strategy  C
# Updated node is  (22, 19)  with strategy  C
# Updated node is  (5, 24)  with strategy  D
# Updated node is  (25, 8)  with strategy  C
# Updated node is  (18, 6)  with strategy  D
# Updated node is  (11, 23)  with strategy  C
# Updated node is  (15, 18)  with strategy  D
# Updated node is  (19, 5)  with strategy  D
# Updated node is  (10, 6)  with strategy  D
# Updated node is  (7, 5)  with strategy  C
# Updated node is  (1, 24)  with strategy  C
# Updated node is  (7, 22)  with strategy  C
# Updated node is  (21, 12)  with strategy  C
# Updated node is  (14, 4)  with strategy  C
# Updated node is  (2, 20)  with strategy  D
# Updated node is  (2, 22)  with strategy  C
# Updated node is  (6, 16)  with strategy  D
# Updated node is  (28, 9)  with strategy  C
# Updated node is  (6, 6)  with strategy  C
# Updated node is  (29, 10)  with strategy  C
# Updated node is  (5, 4)  with strategy  C
# Updated node is  (8, 8)  with strategy  C
# Updated node is  (9, 23)  with strategy  C
# Updated node is  (23, 2)  with strategy  D
# Updated node is  (28, 7)  with strategy  D
# Updated node is  (4, 22)  with strategy  D
# Updated node is  (21, 10)  with strategy  C
# Updated node is  (10, 0)  with strategy  C
# Updated node is  (3, 0)  with strategy  D
# Updated node is  (24, 24)  with strategy  C
# Updated node is  (16, 25)  with strategy  C
# Updated node is  (1, 20)  with strategy  C
# Updated node is  (6, 7)  with strategy  C
# Updated node is  (2, 0)  with strategy  C
# Updated node is  (10, 1)  with strategy  D
# Updated node is  (24, 7)  with strategy  D
# Updated node is  (6, 22)  with strategy  D
# Updated node is  (20, 26)  with strategy  C
# Updated node is  (2, 3)  with strategy  D
# Updated node is  (23, 17)  with strategy  C
# Updated node is  (11, 9)  with strategy  D
# Updated node is  (17, 8)  with strategy  D
# Updated node is  (8, 12)  with strategy  D
# Updated node is  (5, 10)  with strategy  D
# Updated node is  (20, 25)  with strategy  C
# Updated node is  (12, 12)  with strategy  C
# Updated node is  (29, 10)  with strategy  C
# Updated node is  (4, 19)  with strategy  C
# Updated node is  (28, 11)  with strategy  C
# Updated node is  (15, 26)  with strategy  D
# Updated node is  (11, 18)  with strategy  C
# Updated node is  (15, 24)  with strategy  D
# Updated node is  (21, 16)  with strategy  C
# Updated node is  (9, 11)  with strategy  D
# Updated node is  (26, 20)  with strategy  D
# Updated node is  (0, 12)  with strategy  D
# Updated node is  (17, 8)  with strategy  C
# Updated node is  (22, 24)  with strategy  C
# Updated node is  (15, 26)  with strategy  D
# Updated node is  (3, 0)  with strategy  D
# Updated node is  (1, 16)  with strategy  D
# Updated node is  (22, 12)  with strategy  D
# Updated node is  (9, 8)  with strategy  C
# Updated node is  (17, 23)  with strategy  C
# Updated node is  (24, 4)  with strategy  C
# Updated node is  (11, 29)  with strategy  D
# Updated node is  (25, 21)  with strategy  C
# Updated node is  (7, 17)  with strategy  C
# Updated node is  (25, 12)  with strategy  D
# Updated node is  (3, 3)  with strategy  D
# Updated node is  (15, 4)  with strategy  D
# Updated node is  (17, 0)  with strategy  C
# Updated node is  (20, 16)  with strategy  D
# Updated node is  (13, 10)  with strategy  D
# Updated node is  (25, 27)  with strategy  C
# Updated node is  (8, 9)  with strategy  D
# Updated node is  (29, 13)  with strategy  C
# Updated node is  (24, 15)  with strategy  C
# Updated node is  (8, 4)  with strategy  C
# Updated node is  (9, 12)  with strategy  D
# Updated node is  (13, 10)  with strategy  D
# Updated node is  (21, 26)  with strategy  D
# Updated node is  (2, 19)  with strategy  C
# Updated node is  (25, 4)  with strategy  C
# Updated node is  (23, 19)  with strategy  C
# Updated node is  (14, 29)  with strategy  D
# Updated node is  (2, 26)  with strategy  C
# Updated node is  (0, 23)  with strategy  D
# Updated node is  (21, 4)  with strategy  C
# Updated node is  (25, 29)  with strategy  C
# Updated node is  (22, 19)  with strategy  C
# Updated node is  (3, 5)  with strategy  C
# Updated node is  (0, 29)  with strategy  C
# Updated node is  (26, 29)  with strategy  C
# Updated node is  (16, 21)  with strategy  D
# Updated node is  (14, 13)  with strategy  C
# Updated node is  (7, 2)  with strategy  C
# Updated node is  (0, 15)  with strategy  C
# Updated node is  (17, 1)  with strategy  D
# Updated node is  (16, 15)  with strategy  C
# Updated node is  (3, 21)  with strategy  D
# Updated node is  (12, 22)  with strategy  D
# Updated node is  (8, 11)  with strategy  C
# Updated node is  (11, 28)  with strategy  D
# Updated node is  (11, 2)  with strategy  C
# Updated node is  (24, 16)  with strategy  D
# Updated node is  (27, 5)  with strategy  D
# Updated node is  (27, 11)  with strategy  C
# Updated node is  (24, 19)  with strategy  D
# Updated node is  (9, 9)  with strategy  D
# Updated node is  (6, 0)  with strategy  C
# Updated node is  (8, 10)  with strategy  D
# Updated node is  (4, 3)  with strategy  D
# Updated node is  (28, 17)  with strategy  C
# Updated node is  (23, 7)  with strategy  D
# Updated node is  (20, 14)  with strategy  D
# Updated node is  (10, 2)  with strategy  C
# Updated node is  (5, 24)  with strategy  D
# Updated node is  (5, 22)  with strategy  C
# Updated node is  (14, 7)  with strategy  D
# Updated node is  (11, 2)  with strategy  C
# Updated node is  (4, 9)  with strategy  C
# Updated node is  (26, 16)  with strategy  C
# Updated node is  (6, 28)  with strategy  C
# Updated node is  (11, 20)  with strategy  C
# Updated node is  (16, 16)  with strategy  C
# Updated node is  (21, 2)  with strategy  C
# Updated node is  (14, 28)  with strategy  C
# Updated node is  (14, 10)  with strategy  D
# Updated node is  (27, 21)  with strategy  C
# Updated node is  (29, 3)  with strategy  C
# Updated node is  (21, 16)  with strategy  C
# Updated node is  (0, 10)  with strategy  C
# Updated node is  (21, 14)  with strategy  D
# Updated node is  (17, 15)  with strategy  C
# Updated node is  (10, 13)  with strategy  D
# Updated node is  (29, 21)  with strategy  C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Run the simulation and plot the final state
# ----> 2 cooperation_levels, G = simulate()
#       4 # Plot the cooperation level over time
#       5 plt.plot(cooperation_levels)
#
# Cell In[74], line 7, in simulate()
#       4 cooperation_levels = []
#       6 for t in range(100000):  # Simulate for 100 time steps
# ----> 7     payoffs = play_game(G)
#       8     update_strategies(G, payoffs)
#      10     num_cooperators = sum(1 for node in G.nodes() if G.nodes[node]['strategy'] == 'C')
#
# Cell In[72], line 95, in play_game(G)
#      93         payoff += b  # Defector interacting with cooperator
#      94     elif strategy == 'D' and neighbor_strategy == 'D' and site=='poor' and neighbor_site == 'poor':
# ---> 95         payoff += b - 1  # Defector interacting with defector
#      98 # Add cooperation cluster bonus for cooperators
#      99 #if strategy == 'C':
#     100     #payoff += cooperator_neighbors * COOPERATION_CLUSTER_BONUS    # Bonus for each cooperative neighbor
#     102 payoffs[node] = payoff
#
# KeyboardInterrupt:
